# %%
mkdir test1

# %%
rmdir test1

# %%
Nombres_Directorios_ = "materiales.txt"
Enlaces_ = "enlaces.txt"

tuplas = []

with open(Nombres_Directorios_,"r") as minerales, open(Enlaces_,"r") as enlaces:
    Linea_minerales = minerales.readlines()
    Linea_enlaces = enlaces.readlines()

for nombre, descarga in zip(Linea_minerales, Linea_enlaces):
    tupla = (nombre.strip(), descarga.strip())
    tuplas.append(tupla)

print(tuplas)
# Out:
# [('BF1', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/BF1.yml'), ('BF11', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/BF11.yml'), ('BF16', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/BF16.yml'), ('BF21', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/BF21.yml'), ('BF24', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/BF24.yml'), ('BF25', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/BF25.yml'), ('BF28', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/BF28.yml'), ('BF8', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/BF8.yml'), ('BK4', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/BK4.yml'), ('BK10', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/BK10.yml'), ('BK6', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/BK6.yml'), ('BF11', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/BF11.yml'), ('LK7', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/LK7.yml'), ('BK8', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/BK8.yml'), ('CTK12', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/CTK12.yml'), ('CTK19', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/CTK19.yml'), ('CTK3', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/CTK3.yml'), ('CTK8', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/CTK8.yml'), ('CTK9', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/CTK9.yml'), ('F1', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/F1.yml'), ('F13', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/F13.yml'), ('F4', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/F4.yml'), ('F6', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/F6.yml'), ('F8', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/F8.yml'), ('K8', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/K8.yml'), ('KF6', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/KF6.yml'), ('KF7', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/KF7.yml'), ('LF5', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/LF5.yml'), ('LF7', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/LF7.yml'), ('LF9', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-database/master/database/data-nk/glass/lzos/LF9.yml'), ('LK3', 'https://raw.githubusercontent.com/polyanskiy/refractiveindex.info-data ...
